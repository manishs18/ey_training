# %%
from src.pipeline.data_loader import load_data
from src.pipeline.run_evaluation import run

df = load_data("../data/sample_inputs.csv")
results = run(df)

results.sort_values("risk", ascending=False)
